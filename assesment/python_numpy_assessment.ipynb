# %% [markdown]
# Assessment 1

# %%
import pandas as pd

# %% [markdown]
# 1) Import pandas and read in the banklist.csv file into a dataframe called
# banks.

# %%
df= pd.read_csv(r"C:\Users\SORATE DURVESH\Downloads\banklist.csv")
print(df)
# Out:
#                                              Bank Name                City  \
# 0                                  Fayette County Bank          Saint Elmo
# 1    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
# 2                                       First NBC Bank         New Orleans
# 3                                        Proficio Bank  Cottonwood Heights
# 4                        Seaway Bank and Trust Company             Chicago
# ..                                                 ...                 ...
# 548                                 Superior Bank, FSB            Hinsdale
# 549                                Malta National Bank               Malta
# 550                    First Alliance Bank & Trust Co.          Manchester
# 551                  National State Bank of Metropolis          Metropolis
# 552                                   Bank of Honolulu            Honolulu
#
#      ST   CERT                Acquiring Institution Closing Date Updated Date
# 0    IL   1802            United Fidelity Bank, fsb    26-May-17    26-Jul-17
# 1    WI  30003  First-Citizens Bank & Trust Company     5-May-17    26-Jul-17
# 2    LA  58302                         Whitney Bank    28-Apr-17    26-Jul-17
# 3    UT  35495                    Cache Valley Bank     3-Mar-17    18-May-17
# 4    IL  19328                  State Bank of Texas    27-Jan-17    18-May-17
# ..   ..    ...                                  ...          ...          ...
# 548  IL  32646                Superior Federal, FSB    27-Jul-01    19-Aug-14
# 549  OH   6629                    North Valley Bank     3-May-01    18-Nov-02
# 550  NH  34264  Southern New Hampshire Bank & Trust     2-Feb-01    18-Feb-03
# 551  IL   3815              Banterra Bank of Marion    14-Dec-00    17-Mar-05
# 552  HI  21029                   Bank of the Orient    13-Oct-00    17-Mar-05
#
# [553 rows x 7 columns]

# %% [markdown]
# 2) Show the head of the dataframe.

# %%
df.head()
# Out:
#                                            Bank Name                City  ST  \
# 0                                Fayette County Bank          Saint Elmo  IL
# 1  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee  WI
# 2                                     First NBC Bank         New Orleans  LA
# 3                                      Proficio Bank  Cottonwood Heights  UT
# 4                      Seaway Bank and Trust Company             Chicago  IL
#
#     CERT                Acquiring Institution Closing Date Updated Date
# 0   1802            United Fidelity Bank, fsb    26-May-17    26-Jul-17
# 1  30003  First-Citizens Bank & Trust Company     5-May-17    26-Jul-17
# 2  58302                         Whitney Bank    28-Apr-17    26-Jul-17
# 3  35495                    Cache Valley Bank     3-Mar-17    18-May-17
# 4  19328                  State Bank of Texas    27-Jan-17    18-May-17

# %% [markdown]
# 3) What are the column names?

# %%
df.columns
# Out:
# Index(['Bank Name', 'City', 'ST', 'CERT', 'Acquiring Institution',
#        'Closing Date', 'Updated Date'],
#       dtype='object')

# %% [markdown]
# 4) How many States (ST) are represented in this data set?

# %%
df['ST'].nunique()
# Out:
# 44

# %% [markdown]
# 5) Get a list or array of all the states in the data set.

# %%
df['ST'].unique()
# Out:
# array(['IL', 'WI', 'LA', 'UT', 'NJ', 'AR', 'GA', 'PA', 'TN', 'WA', 'CO',
#        'PR', 'FL', 'MN', 'CA', 'MD', 'OK', 'OH', 'SC', 'VA', 'ID', 'TX',
#        'CT', 'AZ', 'NV', 'NC', 'KY', 'MO', 'KS', 'AL', 'MI', 'IN', 'IA',
#        'NE', 'MS', 'NM', 'OR', 'NY', 'MA', 'SD', 'WY', 'WV', 'NH', 'HI'],
#       dtype=object)

# %% [markdown]
# 6) What are the top 5 states with the most failed banks?

# %%
df['ST'].value_counts().head(5)
# Out:
# ST
# GA    93
# FL    75
# IL    68
# CA    41
# MN    23
# Name: count, dtype: int64

# %% [markdown]
# 7) What are the top 5 acquiring institutions?

# %%
df['Acquiring Institution'].value_counts().head(5)
# Out:
# Acquiring Institution
# No Acquirer                            31
# State Bank and Trust Company           12
# First-Citizens Bank & Trust Company    11
# Ameris Bank                            10
# U.S. Bank N.A.                          9
# Name: count, dtype: int64

# %% [markdown]
# 8) How many banks has the State Bank of Texas acquired? How many of
# them were actually in Texas?

# %%
print(((df['Acquiring Institution'] == 'State Bank of Texas').sum(), ((df['Acquiring Institution'] == 'State Bank of Texas') & (df['ST'] == 'TX')).sum()))
# Out:
# (np.int64(3), np.int64(1))

# %% [markdown]
# 9) What is the most common city in California for a bank to fail in?

# %%
print(df[df['ST'] == 'CA']['City'].value_counts().idxmax())
# Out:
# Los Angeles

# %% [markdown]
# Assessment 2:

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df= pd.read_csv(r"C:\Users\SORATE DURVESH\Downloads\historical_automobile_sales.csv")
print(df)
# Out:
#            Date  Year Month  Recession  Consumer_Confidence  \
# 0     1/31/1980  1980   Jan          1               108.24
# 1     2/29/1980  1980   Feb          1                98.75
# 2     3/31/1980  1980   Mar          1               107.48
# 3     4/30/1980  1980   Apr          1               115.01
# 4     5/31/1980  1980   May          1                98.72
# ..          ...   ...   ...        ...                  ...
# 523   8/31/2023  2023   Aug          0               103.36
# 524   9/30/2023  2023   Sep          0               101.55
# 525  10/31/2023  2023   Oct          0               124.66
# 526  11/30/2023  2023   Nov          0                97.09
# 527  12/31/2023  2023   Dec          0                95.92
#
#      Seasonality_Weight      Price  Advertising_Expenditure  Competition  \
# 0                  0.50  27483.571                     1558            7
# 1                  0.75  24308.678                     3048            4
# 2                  0.20  28238.443                     3137            3
# 3                  1.00  32615.149                     1653            7
# 4                  0.20  23829.233                     1319            4
# ..                  ...        ...                      ...          ...
# 523                0.25  27852.993                     1793            6
# 524                0.07  21183.704                     1028            5
# 525                0.12  15975.589                     1148            9
# 526                0.25  16862.288                     4850            5
# 527                0.34  25240.425                     2319            3
#
#         GDP  Growth_Rate  unemployment_rate  Automobile_Sales  \
# 0    60.223     0.010000                5.4             456.0
# 1    45.986    -0.309594                4.8             555.9
# 2    35.141    -0.308614                3.4             620.0
# 3    45.673     0.230596                4.2             702.8
# 4    52.997     0.138197                5.3             770.4
# ..      ...          ...                ...               ...
# 523  57.169     0.764155                2.6            1579.6
# 524  59.315     0.036180                2.5            1123.4
# 525  19.472    -2.046169                2.5            1685.9
# 526  27.904     0.302179                2.9            2124.6
# 527  13.518    -1.064211                2.1            3538.5
#
#         Vehicle_Type        City
# 0      Supperminicar     Georgia
# 1      Supperminicar    New York
# 2    Mediumfamilycar    New York
# 3      Supperminicar    Illinois
# 4    Smallfamiliycar  California
# ..               ...         ...
# 523     Executivecar    New York
# 524  Smallfamiliycar  California
# 525           Sports  California
# 526  Smallfamiliycar     Georgia
# 527  Smallfamiliycar     Georgia
#
# [528 rows x 15 columns]

# %% [markdown]
# Q 1: Develop a Line chart using the functionality of pandas to show how
# automobile sales fluctuate from year to year.

# %%
# Group by Year and sum the automobile sales
yearly_sales = df.groupby('Year')['Automobile_Sales'].sum()

# Plotting
plt.figure(figsize=(10,6))
yearly_sales.plot(kind='line', marker='o', color='green', linewidth=2)
plt.title("Automobile Sales Over Years", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Total Automobile Sales", fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# Q 2: Plot different lines for categories of vehicle type and analyze the trend
# to answer the question Is there a noticeable difference in sales trends
# between different vehicle types during recession periods?

# %%
recession_df = df[df['Recession'] == 1]
vehicle_sales = recession_df.groupby(['Year', 'Vehicle_Type'])['Automobile_Sales'].sum().unstack()
plt.figure(figsize=(12,6))
for vehicle_type in vehicle_sales.columns:
    plt.plot(vehicle_sales.index, vehicle_sales[vehicle_type], marker='o', linewidth=2, label=vehicle_type)

plt.title("Automobile Sales Trends by Vehicle Type During Recession", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Total Automobile Sales", fontsize=12)
plt.legend(title="Vehicle Type")
plt.grid(True)
plt.show()

# %% [markdown]
# Q 3: Use the functionality of Seaborn Library to create a visualization to compare
# the sales trend per vehicle type for a recession period with a non- recession
# period.

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\sorate durvesh\appdata\roaming\python\python313\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\sorate durvesh\appdata\roaming\python\python313\site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\sorate durvesh\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sorate durvesh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\sorate durvesh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sorate durvesh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sorate durvesh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sorate durvesh\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\sorate durvesh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\sorate durvesh\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sorate durvesh\appdata\roaming\python\python313\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sorate durvesh\appdata\roaming\python\python313\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sorate durvesh\appdata\roaming\python\python313\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\sorate durvesh\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns

# %%
# Convert 'Date' column to datetime if needed
df['Date'] = pd.to_datetime(df['Date'])

# Aggregate sales by Year, Vehicle_Type, and Recession
sales_trend = df.groupby(['Year', 'Vehicle_Type', 'Recession'])['Automobile_Sales'].sum().reset_index()

# Map Recession for readability
sales_trend['Recession'] = sales_trend['Recession'].map({1: 'Recession', 0: 'Non-Recession'})

# Plot using Seaborn
plt.figure(figsize=(14,6))
sns.lineplot(
    data=sales_trend, 
    x='Year', 
    y='Automobile_Sales', 
    hue='Vehicle_Type', 
    style='Recession', 
    markers=True, 
    dashes=False
)
plt.title('Automobile Sales Trend by Vehicle Type During Recession vs Non-Recession')
plt.ylabel('Total Sales')
plt.xlabel('Year')
plt.legend(title='Vehicle Type / Period')
plt.show()

# %% [markdown]
# Q 4: Now you want to compare the sales of different vehicle types
# during a recession and a non-recession period

# %%
# Map Recession values for readability
df['Recession'] = df['Recession'].map({1: 'Recession', 0: 'Non-Recession'})

# Aggregate total sales per Vehicle_Type and Recession
vehicle_sales = df.groupby(['Vehicle_Type', 'Recession'])['Automobile_Sales'].sum().reset_index()

# Plot using Seaborn
plt.figure(figsize=(10,6))
sns.barplot(
    data=vehicle_sales,
    x='Vehicle_Type',
    y='Automobile_Sales',
    hue='Recession'
)
plt.title('Total Automobile Sales by Vehicle Type: Recession vs Non-Recession')
plt.ylabel('Total Sales')
plt.xlabel('Vehicle Type')
plt.legend(title='Period')
plt.show()
